# %% [markdown]
# ### Import packages

# %%
import pandas as pd
from pyomo.environ import *
from pyomo.opt import SolverFactory, SolverStatus, TerminationCondition

# %% [markdown]
# ### Create model

# %%
# Define model
m = ConcreteModel()

# Define sets
m.ITEMS = Set(initialize=['A', 'B', 'C'])
m.WEEKS = Set(initialize=range(1,5))

# Define Decision Variable
m.MarkPct = Var(m.ITEMS, m.WEEKS, domain = NonNegativeReals, bounds = (0,1))

# Define Implicit Variables
m.MarkPrice = Var(m.ITEMS, m.WEEKS, domain = NonNegativeReals)
m.Demand = Var(m.ITEMS, m.WEEKS, domain = NonNegativeReals)
m.Revenue = Var(m.ITEMS, m.WEEKS, domain = NonNegativeReals)
m.FinalInv = Var(m.ITEMS, m.WEEKS, domain = NonNegativeReals)

# Define Params
m.basePrice = Param(m.ITEMS, initialize = {'A':21.5, 'B':29.5, 'C': 30.5})
m.initInv = Param(m.ITEMS, initialize = {'A':10, 'B':30, 'C':41})
m.maxPct = 0.80
m.cap = 20
m.dispCost = 1.2

# Define equations for implicit variables

# Define Markdown Price
def Define_MarkPrice_Rule(m,i,w):
    return (1-m.MarkPct[i,w])*m.basePrice[i] == m.MarkPrice[i,w]
m.Define_MarkPrice =  Constraint(m.ITEMS, m.WEEKS, rule = Define_MarkPrice_Rule)

# Define Demand
def Define_Demand_Rule(m,i,w):
    return  m.MarkPct[i,w]*m.initInv[i] == m.Demand[i,w]
m.Define_Demand =  Constraint(m.ITEMS, m.WEEKS, rule = Define_Demand_Rule)

# Define Revenue
def Define_Revenue_Rule(m,i,w):
    return m.MarkPrice[i,w]*m.Demand[i,w] == m.Revenue[i,w]
m.Define_Revenue =  Constraint(m.ITEMS, m.WEEKS, rule = Define_Revenue_Rule)

# Define Final Inv
def Define_FinalInv_Rule(m,i,w):
    if w==1:
        return m.FinalInv[i,w] == m.initInv[i] - m.Demand[i,w]
    else:
        return m.FinalInv[i,w] == m.FinalInv[i,w-1] - m.Demand[i,w]
m.Define_FinalInv =  Constraint(m.ITEMS, m.WEEKS, rule = Define_FinalInv_Rule)


# Add limitations on how soon to markdown and how much (made up in class)
m.maxPctW1 = 0.20
m.maxPct = 0.80
def Limit_Markdown_Week1_Rule(m,i):
    return m.MarkPct[i,1] <= m.maxPctW1
m.Limit_Markdown_Week1 =  Constraint(m.ITEMS, rule = Limit_Markdown_Week1_Rule)


# Define Constraints

# Define max discount
def Max_Discount_Rule(m,i,w):
    return m.MarkPct[i,w] <= m.maxPct
m.Max_Discount = Constraint(m.ITEMS, m.WEEKS, rule = Max_Discount_Rule)  

# Sell such that leftover inventory is less than min Inv
def Leftover_Inv_Rule(m,i):
     return m.FinalInv[i,4] <= m.cap
m.Leftover_Inv_Rule = Constraint(m.ITEMS, rule = Leftover_Inv_Rule)


# Define Objective Function
def Max_Revenue_Rule(m):
    return sum(m.Revenue[i,w] for i in m.ITEMS for w in m.WEEKS) - sum(m.dispCost*m.FinalInv[i,4] for i in m.ITEMS)
m.Max_Revenue = Objective(rule = Max_Revenue_Rule, sense = maximize)

# %% [markdown]
# ### Solve

# %%
solver = SolverFactory('ipopt')
solution = solver.solve(m)

# %% [markdown]
# Check the status of the solver

# %%
print(solution['Solver'])
# Out:
# - Status: ok
#   Message: Ipopt 3.14.16\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.02962946891784668

# %% [markdown]
# ### Extract Optimum Values

# %% [markdown]
# Print optimum value of objective function

# %%
print(m.Max_Revenue.expr())
# Out:
# 1755.0400035352961

# %% [markdown]
# Print optimum value of decision and implicit variables - Option 2 (generic, same syntax will work for other use cases)

# %%
data = {'Variable': [], 'Value': []}
for var in m.component_objects(Var):
    for index in var:
        data['Variable'].append(f'{var.name}[{index}]')
        data['Value'].append(var[index].value)
pd.DataFrame(data)
# Out:
#                Variable         Value
# 0     MarkPct[('A', 1)]  2.000000e-01
# 1     MarkPct[('A', 2)]  2.666667e-01
# 2     MarkPct[('A', 3)]  2.666667e-01
# 3     MarkPct[('A', 4)]  2.666667e-01
# 4     MarkPct[('B', 1)]  2.000000e-01
# 5     MarkPct[('B', 2)]  2.666667e-01
# 6     MarkPct[('B', 3)]  2.666667e-01
# 7     MarkPct[('B', 4)]  2.666667e-01
# 8     MarkPct[('C', 1)]  2.000000e-01
# 9     MarkPct[('C', 2)]  2.666667e-01
# 10    MarkPct[('C', 3)]  2.666667e-01
# 11    MarkPct[('C', 4)]  2.666667e-01
# 12  MarkPrice[('A', 1)]  1.720000e+01
# 13  MarkPrice[('A', 2)]  1.576667e+01
# 14  MarkPrice[('A', 3)]  1.576667e+01
# 15  MarkPrice[('A', 4)]  1.576667e+01
# 16  MarkPrice[('B', 1)]  2.360000e+01
# 17  MarkPrice[('B', 2)]  2.163333e+01
# 18  MarkPrice[('B', 3)]  2.163333e+01
# 19  MarkPrice[('B', 4)]  2.163333e+01
# 20  MarkPrice[('C', 1)]  2.440000e+01
# 21  MarkPrice[('C', 2)]  2.236667e+01
# 22  MarkPrice[('C', 3)]  2.236667e+01
# 23  MarkPrice[('C', 4)]  2.236667e+01
# 24     Demand[('A', 1)]  2.000000e+00
# 25     Demand[('A', 2)]  2.666667e+00
# 26     Demand[('A', 3)]  2.666667e+00
# 27     Demand[('A', 4)]  2.666667e+00
# 28     Demand[('B', 1)]  6.000000e+00
# 29     Demand[('B', 2)]  8.000000e+00
# 30     Demand[('B', 3)]  8.000000e+00
# 31     Demand[('B', 4)]  8.000000e+00
# 32     Demand[('C', 1)]  8.200000e+00
# 33     Demand[('C', 2)]  1.093333e+01
# 34     Demand[('C', 3)]  1.093333e+01
# 35     Demand[('C', 4)]  1.093333e+01
# 36    Revenue[('A', 1)]  3.440000e+01
# 37    Revenue[('A', 2)]  4.204444e+01
# 38    Revenue[('A', 3)]  4.204444e+01
# 39    Revenue[('A', 4)]  4.204444e+01
# 40    Revenue[('B', 1)]  1.416000e+02
# 41    Revenue[('B', 2)]  1.730667e+02
# 42    Revenue[('B', 3)]  1.730667e+02
# 43    Revenue[('B', 4)]  1.730667e+02
# 44    Revenue[('C', 1)]  2.000800e+02
# 45    Revenue[('C', 2)]  2.445422e+02
# 46    Revenue[('C', 3)]  2.445422e+02
# 47    Revenue[('C', 4)]  2.445422e+02
# 48   FinalInv[('A', 1)]  8.000000e+00
# 49   FinalInv[('A', 2)]  5.333333e+00
# 50   FinalInv[('A', 3)]  2.666667e+00
# 51   FinalInv[('A', 4)] -9.776926e-09
# 52   FinalInv[('B', 1)]  2.400000e+01
# 53   FinalInv[('B', 2)]  1.600000e+01
# 54   FinalInv[('B', 3)]  8.000000e+00
# 55   FinalInv[('B', 4)] -9.832568e-09
# 56   FinalInv[('C', 1)]  3.280000e+01
# 57   FinalInv[('C', 2)]  2.186667e+01
# 58   FinalInv[('C', 3)]  1.093333e+01
# 59   FinalInv[('C', 4)] -9.837630e-09

# %%
m.display()
# Out:
# Model unknown
#
#   Variables:
#     MarkPct : Size=12, Index=ITEMS*WEEKS
#         Key      : Lower : Value               : Upper : Fixed : Stale : Domain
#         ('A', 1) :     0 :  0.2000000099125034 :     1 : False : False : NonNegativeReals
#         ('A', 2) :     0 :  0.2666666636738239 :     1 : False : False : NonNegativeReals
#         ('A', 3) :     0 :  0.2666666636847529 :     1 : False : False : NonNegativeReals
#         ('A', 4) :     0 : 0.26666666370661246 :     1 : False : False : NonNegativeReals
#         ('B', 1) :     0 : 0.20000000997875883 :     1 : False : False : NonNegativeReals
#         ('B', 2) :     0 :  0.2666666634461252 :     1 : False : False : NonNegativeReals
#         ('B', 3) :     0 :  0.2666666634487796 :     1 : False : False : NonNegativeReals
#         ('B', 4) :     0 : 0.26666666345408857 :     1 : False : False : NonNegativeReals
#         ('C', 1) :     0 : 0.20000000998496825 :     1 : False : False : NonNegativeReals
#         ('C', 2) :     0 :    0.26666666341582 :     1 : False : False : NonNegativeReals
#         ('C', 3) :     0 :  0.2666666634176984 :     1 : False : False : NonNegativeReals
#         ('C', 4) :     0 : 0.26666666342145556 :     1 : False : False : NonNegativeReals
#     MarkPrice : Size=12, Index=ITEMS*WEEKS
#         Key      : Lower : Value              : Upper : Fixed : Stale : Domain
#         ('A', 1) :     0 : 17.199999786881175 :  None : False : False : NonNegativeReals
#         ('A', 2) :     0 : 15.766666731012785 :  None : False : False : NonNegativeReals
#         ('A', 3) :     0 : 15.766666730777812 :  None : False : False : NonNegativeReals
#         ('A', 4) :     0 : 15.766666730307833 :  None : False : False : NonNegativeReals
#         ('B', 1) :     0 : 23.599999705626615 :  None : False : False : NonNegativeReals
#         ('B', 2) :     0 : 21.633333428339306 :  None : False : False : NonNegativeReals
#         ('B', 3) :     0 : 21.633333428261004 :  None : False : False : NonNegativeReals
#         ('B', 4) :     0 : 21.633333428104386 :  None : False : False : NonNegativeReals
#         ('C', 1) :     0 :  24.39999969545847 :  None : False : False : NonNegativeReals
#         ('C', 2) :     0 : 22.366666765817488 :  None : False : False : NonNegativeReals
#         ('C', 3) :     0 :   22.3666667657602 :  None : False : False : NonNegativeReals
#         ('C', 4) :     0 : 22.366666765645608 :  None : False : False : NonNegativeReals
#     Demand : Size=12, Index=ITEMS*WEEKS
#         Key      : Lower : Value              : Upper : Fixed : Stale : Domain
#         ('A', 1) :     0 :  2.000000099125034 :  None : False : False : NonNegativeReals
#         ('A', 2) :     0 : 2.6666666367382392 :  None : False : False : NonNegativeReals
#         ('A', 3) :     0 : 2.6666666368475287 :  None : False : False : NonNegativeReals
#         ('A', 4) :     0 : 2.6666666370661245 :  None : False : False : NonNegativeReals
#         ('B', 1) :     0 :  6.000000299362765 :  None : False : False : NonNegativeReals
#         ('B', 2) :     0 :  7.999999903383757 :  None : False : False : NonNegativeReals
#         ('B', 3) :     0 : 7.9999999034633875 :  None : False : False : NonNegativeReals
#         ('B', 4) :     0 :  7.999999903622658 :  None : False : False : NonNegativeReals
#         ('C', 1) :     0 :  8.200000409383698 :  None : False : False : NonNegativeReals
#         ('C', 2) :     0 :  10.93333320004862 :  None : False : False : NonNegativeReals
#         ('C', 3) :     0 : 10.933333200125636 :  None : False : False : NonNegativeReals
#         ('C', 4) :     0 : 10.933333200279678 :  None : False : False : NonNegativeReals
#     Revenue : Size=12, Index=ITEMS*WEEKS
#         Key      : Lower : Value              : Upper : Fixed : Stale : Domain
#         ('A', 1) :     0 :  34.40000127871382 :  None : False : False : NonNegativeReals
#         ('A', 2) :     0 : 42.044444144162554 :  None : False : False : NonNegativeReals
#         ('A', 3) :     0 :  42.04444414525912 :  None : False : False : NonNegativeReals
#         ('A', 4) :     0 :  42.04444414745252 :  None : False : False : NonNegativeReals
#         ('B', 1) :     0 : 141.60000529872107 :  None : False : False : NonNegativeReals
#         ('B', 2) :     0 : 173.06666533658304 :  None : False : False : NonNegativeReals
#         ('B', 3) :     0 : 173.06666533767932 :  None : False : False : NonNegativeReals
#         ('B', 4) :     0 : 173.06666533987195 :  None : False : False : NonNegativeReals
#         ('C', 1) :     0 :  200.0800074917217 :  None : False : False : NonNegativeReals
#         ('C', 2) :     0 : 244.54222032513647 :  None : False : False : NonNegativeReals
#         ('C', 3) :     0 : 244.54222032623267 :  None : False : False : NonNegativeReals
#         ('C', 4) :     0 :  244.5422203284252 :  None : False : False : NonNegativeReals
#     FinalInv : Size=12, Index=ITEMS*WEEKS
#         Key      : Lower : Value                  : Upper : Fixed : Stale : Domain
#         ('A', 1) :     0 :     7.9999999008749665 :  None : False : False : NonNegativeReals
#         ('A', 2) :     0 :      5.333333264136727 :  None : False : False : NonNegativeReals
#         ('A', 3) :     0 :      2.666666627289199 :  None : False : False : NonNegativeReals
#         ('A', 4) :     0 : -9.776925553503673e-09 :  None : False : False : NonNegativeReals
#         ('B', 1) :     0 :     23.999999700637236 :  None : False : False : NonNegativeReals
#         ('B', 2) :     0 :     15.999999797253478 :  None : False : False : NonNegativeReals
#         ('B', 3) :     0 :      7.999999893790091 :  None : False : False : NonNegativeReals
#         ('B', 4) :     0 : -9.832567713390336e-09 :  None : False : False : NonNegativeReals
#         ('C', 1) :     0 :       32.7999995906163 :  None : False : False : NonNegativeReals
#         ('C', 2) :     0 :     21.866666390567683 :  None : False : False : NonNegativeReals
#         ('C', 3) :     0 :     10.933333190442047 :  None : False : False : NonNegativeReals
#         ('C', 4) :     0 : -9.837630262212991e-09 :  None : False : False : NonNegativeReals
#
#   Objectives:
#     Max_Revenue : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 1755.0400035352961
#
#   Constraints:
#     Define_MarkPrice : Size=12
#         Key      : Lower : Body                   : Upper
#         ('A', 1) :   0.0 :                    0.0 :   0.0
#         ('A', 2) :   0.0 :                    0.0 :   0.0
#         ('A', 3) :   0.0 :                    0.0 :   0.0
#         ('A', 4) :   0.0 :                    0.0 :   0.0
#         ('B', 1) :   0.0 : -3.552713678800501e-15 :   0.0
#         ('B', 2) :   0.0 :                    0.0 :   0.0
#         ('B', 3) :   0.0 :                    0.0 :   0.0
#         ('B', 4) :   0.0 :                    0.0 :   0.0
#         ('C', 1) :   0.0 :                    0.0 :   0.0
#         ('C', 2) :   0.0 :                    0.0 :   0.0
#         ('C', 3) :   0.0 :                    0.0 :   0.0
#         ('C', 4) :   0.0 : -3.552713678800501e-15 :   0.0
#     Define_Demand : Size=12
#         Key      : Lower : Body                    : Upper
#         ('A', 1) :   0.0 :                     0.0 :   0.0
#         ('A', 2) :   0.0 :                     0.0 :   0.0
#         ('A', 3) :   0.0 :                     0.0 :   0.0
#         ('A', 4) :   0.0 :                     0.0 :   0.0
#         ('B', 1) :   0.0 :                     0.0 :   0.0
#         ('B', 2) :   0.0 :  -8.881784197001252e-16 :   0.0
#         ('B', 3) :   0.0 :                     0.0 :   0.0
#         ('B', 4) :   0.0 :  -8.881784197001252e-16 :   0.0
#         ('C', 1) :   0.0 :                     0.0 :   0.0
#         ('C', 2) :   0.0 :                     0.0 :   0.0
#         ('C', 3) :   0.0 : -1.7763568394002505e-15 :   0.0
#         ('C', 4) :   0.0 :                     0.0 :   0.0
#     Define_Revenue : Size=12
#         Key      : Lower : Body                    : Upper
#         ('A', 1) :   0.0 :  -9.094947017729282e-13 :   0.0
#         ('A', 2) :   0.0 :                     0.0 :   0.0
#         ('A', 3) :   0.0 :  -2.842170943040401e-14 :   0.0
#         ('A', 4) :   0.0 : -1.8474111129762605e-13 :   0.0
#         ('B', 1) :   0.0 : -2.2737367544323206e-13 :   0.0
#         ('B', 2) :   0.0 :                     0.0 :   0.0
#         ('B', 3) :   0.0 :  -2.842170943040401e-14 :   0.0
#         ('B', 4) :   0.0 :  -2.842170943040401e-14 :   0.0
#         ('C', 1) :   0.0 : -1.4210854715202004e-13 :   0.0
#         ('C', 2) :   0.0 :  -2.842170943040401e-14 :   0.0
#         ('C', 3) :   0.0 :   2.842170943040401e-14 :   0.0
#         ('C', 4) :   0.0 :                     0.0 :   0.0
#     Define_FinalInv : Size=12
#         Key      : Lower : Body                    : Upper
#         ('A', 1) :   0.0 :                     0.0 :   0.0
#         ('A', 2) :   0.0 :                     0.0 :   0.0
#         ('A', 3) :   0.0 :   4.440892098500626e-16 :   0.0
#         ('A', 4) :   0.0 :   -6.20810564075174e-17 :   0.0
#         ('B', 1) :   0.0 :                     0.0 :   0.0
#         ('B', 2) :   0.0 : -1.7763568394002505e-15 :   0.0
#         ('B', 3) :   0.0 :                     0.0 :   0.0
#         ('B', 4) :   0.0 :  -6.441955555620891e-17 :   0.0
#         ('C', 1) :   0.0 :                     0.0 :   0.0
#         ('C', 2) :   0.0 :   3.552713678800501e-15 :   0.0
#         ('C', 3) :   0.0 :                     0.0 :   0.0
#         ('C', 4) :   0.0 :    8.91928499255416e-16 :   0.0
#     Limit_Markdown_Week1 : Size=3
#         Key : Lower : Body                : Upper
#           A :  None :  0.2000000099125034 :   0.2
#           B :  None : 0.20000000997875883 :   0.2
#           C :  None : 0.20000000998496825 :   0.2
#     Max_Discount : Size=12
#         Key      : Lower : Body                : Upper
#         ('A', 1) :  None :  0.2000000099125034 :   0.8
#         ('A', 2) :  None :  0.2666666636738239 :   0.8
#         ('A', 3) :  None :  0.2666666636847529 :   0.8
#         ('A', 4) :  None : 0.26666666370661246 :   0.8
#         ('B', 1) :  None : 0.20000000997875883 :   0.8
#         ('B', 2) :  None :  0.2666666634461252 :   0.8
#         ('B', 3) :  None :  0.2666666634487796 :   0.8
#         ('B', 4) :  None : 0.26666666345408857 :   0.8
#         ('C', 1) :  None : 0.20000000998496825 :   0.8
#         ('C', 2) :  None :    0.26666666341582 :   0.8
#         ('C', 3) :  None :  0.2666666634176984 :   0.8
#         ('C', 4) :  None : 0.26666666342145556 :   0.8
#     Leftover_Inv_Rule : Size=3
#         Key : Lower : Body                   : Upper
#           A :  None : -9.776925553503673e-09 :  20.0
#           B :  None : -9.832567713390336e-09 :  20.0
#           C :  None : -9.837630262212991e-09 :  20.0
